# %%
import numpy as np
import pandas as pd

# %%
! pip install openpyxl

# %%
url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/Canada.xlsx'
df_can = pd.read_excel(url, sheet_name='Canada by Citizenship',
                      skiprows=range(20),
                      skipfooter=2
                      )
print('data was loaded')
# Out:
# data was loaded

# %%
df_can.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...  2012  2013  \
# 0    Southern Asia  902  Developing regions    16  ...  2635  2004
# 1  Southern Europe  901   Developed regions     1  ...   620   603
# 2  Northern Africa  902  Developing regions    80  ...  3774  4331
# 3        Polynesia  902  Developing regions     0  ...     0     0
# 4  Southern Europe  901   Developed regions     0  ...     1     1
#
#    Unnamed: 43  Unnamed: 44  Unnamed: 45  Unnamed: 46  Unnamed: 47  \
# 0          NaN          NaN          NaN          NaN          NaN
# ...

# %%
df_can.isnull()
# Out:
#       Type  Coverage  OdName   AREA  AreaName    REG  RegName    DEV  DevName  \
# 0    False     False   False  False     False  False    False  False    False
# 1    False     False   False  False     False  False    False  False    False
# 2    False     False   False  False     False  False    False  False    False
# 3    False     False   False  False     False  False    False  False    False
# 4    False     False   False  False     False  False    False  False    False
# ..     ...       ...     ...    ...       ...    ...      ...    ...      ...
# 190  False     False   False  False     False  False    False  False    False
# 191  False     False   False  False     False  False    False  False    False
# 192  False     False   False  False     False  False    False  False    False
# 193  False     False   False  False     False  False    False  False    False
# 194  False     False   False  False     False  False    False  False    False
#
# ...

# %%
df_can.drop(['Type', 'Coverage', 'AREA', 'REG', 'DEV'], axis=1, inplace=True)
df_can
# Out:
#              OdName AreaName             RegName             DevName  1980  \
# 0       Afghanistan     Asia       Southern Asia  Developing regions    16
# 1           Albania   Europe     Southern Europe   Developed regions     1
# 2           Algeria   Africa     Northern Africa  Developing regions    80
# 3    American Samoa  Oceania           Polynesia  Developing regions     0
# 4           Andorra   Europe     Southern Europe   Developed regions     0
# ..              ...      ...                 ...                 ...   ...
# 190        Viet Nam     Asia  South-Eastern Asia  Developing regions  1191
# 191  Western Sahara   Africa     Northern Africa  Developing regions     0
# 192           Yemen     Asia        Western Asia  Developing regions     1
# 193          Zambia   Africa      Eastern Africa  Developing regions    11
# 194        Zimbabwe   Africa      Eastern Africa  Developing regions    72
#
# ...

# %%
df_can.shape
# Out:
# (195, 46)

# %%
df_can.rename(columns={'OdName':'Country', 'AreaName':'Continent', 'RegName':'Region'}, inplace=True)
df_can
# Out:
#             Country Continent              Region             DevName  1980  \
# 0       Afghanistan      Asia       Southern Asia  Developing regions    16
# 1           Albania    Europe     Southern Europe   Developed regions     1
# 2           Algeria    Africa     Northern Africa  Developing regions    80
# 3    American Samoa   Oceania           Polynesia  Developing regions     0
# 4           Andorra    Europe     Southern Europe   Developed regions     0
# ..              ...       ...                 ...                 ...   ...
# 190        Viet Nam      Asia  South-Eastern Asia  Developing regions  1191
# 191  Western Sahara    Africa     Northern Africa  Developing regions     0
# 192           Yemen      Asia        Western Asia  Developing regions     1
# 193          Zambia    Africa      Eastern Africa  Developing regions    11
# 194        Zimbabwe    Africa      Eastern Africa  Developing regions    72
#
# ...

# %%
df_can.dropna(axis=1)
# Out:
#             Country Continent              Region             DevName  1980  \
# 0       Afghanistan      Asia       Southern Asia  Developing regions    16
# 1           Albania    Europe     Southern Europe   Developed regions     1
# 2           Algeria    Africa     Northern Africa  Developing regions    80
# 3    American Samoa   Oceania           Polynesia  Developing regions     0
# 4           Andorra    Europe     Southern Europe   Developed regions     0
# ..              ...       ...                 ...                 ...   ...
# 190        Viet Nam      Asia  South-Eastern Asia  Developing regions  1191
# 191  Western Sahara    Africa     Northern Africa  Developing regions     0
# 192           Yemen      Asia        Western Asia  Developing regions     1
# 193          Zambia    Africa      Eastern Africa  Developing regions    11
# 194        Zimbabwe    Africa      Eastern Africa  Developing regions    72
#
# ...

# %%
df_can.columns = list(map(str,df_can.columns))
years = list(map(str, range(1980, 2014)))
print('data dimentions:', df_can.shape)
# Out:
# data dimentions: (195, 46)

# %%
df_can.set_index('Country', inplace=True)
df_can
# Out:
#                Continent              Region             DevName  1980  1981  \
# Country
# Afghanistan         Asia       Southern Asia  Developing regions    16    39
# Albania           Europe     Southern Europe   Developed regions     1     0
# Algeria           Africa     Northern Africa  Developing regions    80    67
# American Samoa   Oceania           Polynesia  Developing regions     0     1
# Andorra           Europe     Southern Europe   Developed regions     0     0
# ...                  ...                 ...                 ...   ...   ...
# Viet Nam            Asia  South-Eastern Asia  Developing regions  1191  1829
# Western Sahara    Africa     Northern Africa  Developing regions     0     0
# Yemen               Asia        Western Asia  Developing regions     1     2
# Zambia            Africa      Eastern Africa  Developing regions    11    17
# Zimbabwe          Africa      Eastern Africa  Developing regions    72   114
#
# ...

# %%
df_can.dropna(axis=1)
# Out:
#                Continent              Region             DevName  1980  1981  \
# Country
# Afghanistan         Asia       Southern Asia  Developing regions    16    39
# Albania           Europe     Southern Europe   Developed regions     1     0
# Algeria           Africa     Northern Africa  Developing regions    80    67
# American Samoa   Oceania           Polynesia  Developing regions     0     1
# Andorra           Europe     Southern Europe   Developed regions     0     0
# ...                  ...                 ...                 ...   ...   ...
# Viet Nam            Asia  South-Eastern Asia  Developing regions  1191  1829
# Western Sahara    Africa     Northern Africa  Developing regions     0     0
# Yemen               Asia        Western Asia  Developing regions     1     2
# Zambia            Africa      Eastern Africa  Developing regions    11    17
# Zimbabwe          Africa      Eastern Africa  Developing regions    72   114
#
# ...

# %%
df_can
# Out:
#                Continent              Region             DevName  1980  1981  \
# Country
# Afghanistan         Asia       Southern Asia  Developing regions    16    39
# Albania           Europe     Southern Europe   Developed regions     1     0
# Algeria           Africa     Northern Africa  Developing regions    80    67
# American Samoa   Oceania           Polynesia  Developing regions     0     1
# Andorra           Europe     Southern Europe   Developed regions     0     0
# ...                  ...                 ...                 ...   ...   ...
# Viet Nam            Asia  South-Eastern Asia  Developing regions  1191  1829
# Western Sahara    Africa     Northern Africa  Developing regions     0     0
# Yemen               Asia        Western Asia  Developing regions     1     2
# Zambia            Africa      Eastern Africa  Developing regions    11    17
# Zimbabwe          Africa      Eastern Africa  Developing regions    72   114
#
# ...

# %%
# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.style.use('ggplot')

# %%
df_can['Total'] = df_can.sum(axis=1)
df_can
# Out:
#                Continent              Region             DevName  1980  1981  \
# Country
# Afghanistan         Asia       Southern Asia  Developing regions    16    39
# Albania           Europe     Southern Europe   Developed regions     1     0
# Algeria           Africa     Northern Africa  Developing regions    80    67
# American Samoa   Oceania           Polynesia  Developing regions     0     1
# Andorra           Europe     Southern Europe   Developed regions     0     0
# ...                  ...                 ...                 ...   ...   ...
# Viet Nam            Asia  South-Eastern Asia  Developing regions  1191  1829
# Western Sahara    Africa     Northern Africa  Developing regions     0     0
# Yemen               Asia        Western Asia  Developing regions     1     2
# Zambia            Africa      Eastern Africa  Developing regions    11    17
# Zimbabwe          Africa      Eastern Africa  Developing regions    72   114
#
# ...

# %%
df_continents = df_can.groupby('Continent', axis=0).sum()
type(df_continents)
df_continents.head()
# Out:
#                                   1980   1981   1982   1983   1984   1985  \
# Continent
# Africa                            3951   4363   3819   2671   2639   2650
# Asia                             31025  34314  30214  24696  27274  23850
# Europe                           39760  44802  42720  24638  22287  20844
# Latin America and the Caribbean  13081  15215  16769  15427  13678  15171
# Northern America                  9378  10030   9074   7100   6661   6543
#
#                                   1986   1987   1988   1989  ...    2013  \
# Continent                                                    ...
# Africa                            3782   7494   7552   9894  ...   38543
# Asia                             28739  43203  47454  60256  ...  155075
# Europe                           24370  46698  54726  60893  ...   28691
# Latin America and the Caribbean  21179  28471  21924  25060  ...   24950
# Northern America                  7074   7705   6469   6790  ...    8503
#
# ...

# %%
colors_list=['gold','yellowgreen','lightcoral','lightskyblue','lightgreen','pink']
explode_list=[0.1,0, 0, 0,0.1,0.1]

df_continents['Total'].plot(kind='pie', 
                           figsize=(6,6), 
                           autopct='%1.1f%%',
                           startangle=90,
                           shadow=True,
                           labels=None,
                           colors=colors_list, 
                           explode=explode_list)
plt.title('Immigrants by continent to Canada through 1980-2013', y=1.12)
plt.legend(labels=df_continents.index, loc='upper left')
plt.show()

# %%
colors_list=['gold','yellowgreen','lightcoral','lightskyblue','lightgreen','pink']
explode_list=[0.1,0, 0, 0,0.1,0.1]

df_continents['Total'].plot(kind='pie',
                           figsize=(15,10), 
                           autopct='%1.1f%%', 
                           startangle=90, 
                           shadow=True, 
                           labels=None,
                           colors=colors_list,
                           explode=explode_list)
plt.title('Immigrants by continent to Canada through 1980-2013', y=1.12)
plt.axis('equal')
plt.legend(labels=df_continents.index, loc='upper left') 
plt.show()

# %%
df_continents
# Out:
#                                   1980   1981   1982   1983   1984   1985  \
# Continent
# Africa                            3951   4363   3819   2671   2639   2650
# Asia                             31025  34314  30214  24696  27274  23850
# Europe                           39760  44802  42720  24638  22287  20844
# Latin America and the Caribbean  13081  15215  16769  15427  13678  15171
# Northern America                  9378  10030   9074   7100   6661   6543
# Oceania                           1942   1839   1675   1018    878    920
#
#                                   1986   1987   1988   1989  ...    2013  \
# Continent                                                    ...
# Africa                            3782   7494   7552   9894  ...   38543
# Asia                             28739  43203  47454  60256  ...  155075
# Europe                           24370  46698  54726  60893  ...   28691
# Latin America and the Caribbean  21179  28471  21924  25060  ...   24950
# ...

# %%
isinstance(str, type(df_continents.columns))
# Out:
# False

# %%
df_continents.columns = list(map(str, df_continents.columns))

# %%
df_2013=df_continents['2013']
df_2013
# Out:
# Continent
# Africa                              38543
# Asia                               155075
# Europe                              28691
# Latin America and the Caribbean     24950
# Northern America                     8503
# Oceania                              1775
# Name: 2013, dtype: int64

# %%
colors_list=['gold','yellowgreen','lightcoral','lightskyblue','lightgreen','pink']
explode_list=[0.1,0, 0, 0,0.1,0.1]
fonttitle = {'fontname':'Arial', 'size':'30'}


df_2013.plot(kind='pie',
            figsize=(15,10), 
            autopct='%1.1f%%', 
            startangle=90,
            labels=None,
            shadow=True, 
            colors=colors_list,
            explode=explode_list)
plt.title('Immigrants by continent to Canada through 2013', y=1.12, **fonttitle)
plt.axis('equal')
plt.legend(labels=df_continents.index, loc='upper left') 
plt.show()

# %%
df_can.columns = list(map(str,df_can.columns))

# %%
df_Japan=df_can.loc[['Japan'], years].transpose()
df_Japan
# Out:
# Country  Japan
# 1980       701
# 1981       756
# 1982       598
# 1983       309
# 1984       246
# 1985       198
# 1986       248
# 1987       422
# 1988       324
# 1989       494
# 1990       379
# 1991       506
# 1992       605
# 1993       907
# 1994       956
# 1995       826
# 1996       994
# 1997       924
# 1998       897
# 1999      1083
# 2000      1010
# 2001      1092
# 2002       806
# 2003       817
# 2004       973
# 2005      1067
# 2006      1212
# 2007      1250
# 2008      1284
# 2009      1194
# 2010      1168
# 2011      1265
# 2012      1214
# 2013       982

# %%
df_Japan.plot(kind='box')
plt.title('Box plot of Japanese Immigrants from 1980 - 2013')
plt.ylabel('Number of Immigrants')

plt.show()

# %%
df_Japan.describe()
# Out:
# Country        Japan
# count      34.000000
# mean      814.911765
# std       337.219771
# min       198.000000
# 25%       529.000000
# 50%       902.000000
# 75%      1079.000000
# max      1284.000000

# %%
df_China_India = df_can.loc[['China', 'India'], years].transpose()
df_China_India
# Out:
# Country  China  India
# 1980      5123   8880
# 1981      6682   8670
# 1982      3308   8147
# 1983      1863   7338
# 1984      1527   5704
# 1985      1816   4211
# 1986      1960   7150
# 1987      2643  10189
# 1988      2758  11522
# 1989      4323  10343
# 1990      8076  12041
# 1991     14255  13734
# 1992     10846  13673
# 1993      9817  21496
# 1994     13128  18620
# 1995     14398  18489
# 1996     19415  23859
# 1997     20475  22268
# 1998     21049  17241
# 1999     30069  18974
# 2000     35529  28572
# 2001     36434  31223
# 2002     31961  31889
# 2003     36439  27155
# 2004     36619  28235
# 2005     42584  36210
# 2006     33518  33848
# 2007     27642  28742
# 2008     30037  28261
# 2009     29622  29456
# 2010     30391  34235
# 2011     28502  27509
# 2012     33024  30933
# 2013     34129  33087

# %%
df_China_India.plot(kind='box')
plt.title('Comparison of China and India Immigrants from 1980 - 2013')
plt.ylabel('Number of Immigrants')

plt.show()

# %%
df_China_India.plot(kind='box', color='blue', vert=False)
plt.title('Comparison of China and India Immigrants from 1980 - 2013')
plt.xlabel('Number of Immigrants')

plt.show()

# %%
fig = plt.figure() #creating a figure

# artist layer
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

#ax1 subplot details: boxplot
df_China_India.plot(kind='box', vert=False, figsize=(20,6), ax=ax1)
ax1.set_title("Box plot for India and China immigrants to Canada")
ax1.set_xlabel('Number of immigrants')

#ax2 subplot details: line plot
df_China_India.plot(kind='line', figsize=(20,6), ax=ax2)
ax2.set_title("line plot for India and China immigrants to Canada")
ax2.set_xlabel('Years')
ax2.set_ylabel('Number of immigrants')
plt.show()

# %%
df_top15 = df_can.sort_values(['Total'], ascending=False, axis=0).head(15)
df_top15
# Out:
#                                                                           Continent  \
# Country
# India                                                                          Asia
# China                                                                          Asia
# United Kingdom of Great Britain and Northern Ir...                           Europe
# Philippines                                                                    Asia
# Pakistan                                                                       Asia
# United States of America                                           Northern America
# Iran (Islamic Republic of)                                                     Asia
# Sri Lanka                                                                      Asia
# Republic of Korea                                                              Asia
# Poland                                                                       Europe
# ...

# %%
df_top15=df_top15.loc[:,years]
df_top15
# Out:
#                                                      1980   1981   1982  \
# Country
# India                                                8880   8670   8147
# China                                                5123   6682   3308
# United Kingdom of Great Britain and Northern Ir...  22045  24796  20620
# Philippines                                          6051   5921   5249
# Pakistan                                              978    972   1201
# United States of America                             9378  10030   9074
# Iran (Islamic Republic of)                           1172   1429   1822
# Sri Lanka                                             185    371    290
# Republic of Korea                                    1011   1456   1572
# Poland                                                863   2930   5881
# Lebanon                                              1409   1119   1159
# France                                               1729   2027   2219
# ...

# %%
df_top15 = df_top15.transpose()
df_top15
# Out:
#                                                      1980   1981   1982  \
# Country
# India                                                8880   8670   8147
# China                                                5123   6682   3308
# United Kingdom of Great Britain and Northern Ir...  22045  24796  20620
# Philippines                                          6051   5921   5249
# Pakistan                                              978    972   1201
# United States of America                             9378  10030   9074
# Iran (Islamic Republic of)                           1172   1429   1822
# Sri Lanka                                             185    371    290
# Republic of Korea                                    1011   1456   1572
# Poland                                                863   2930   5881
# Lebanon                                              1409   1119   1159
# France                                               1729   2027   2219
# ...

# %%
# creating a list of decades
years_80 = list(map(str, range(1980,1990)))
years_90 = list(map(str, range(1990,2000)))
years_00 = list(map(str, range(2000,2010)))

#slicing the original top15 dataframe
df_80 = df_top15.loc[:, years_80].sum(axis=1)
df_90 = df_top15.loc[:, years_90].sum(axis=1)
df_00 = df_top15.loc[:, years_00].sum(axis=1)


df_decades = pd.DataFrame({'1980': df_80, '1990': df_90, '2000':df_00})
df_decades.head()
# Out:
#                                                       1980    1990    2000
# Country
# India                                                82154  180395  303591
# China                                                32003  161528  340385
# United Kingdom of Great Britain and Northern Ir...  179171  261966   83413
# Philippines                                          60764  138482  172904
# Pakistan                                             10591   65302  127598

# %%
df_decades.transpose()
df_decades.plot(kind='box', figsize = (20,10))
plt.xlabel('decades')
plt.ylabel('Number of immigrants to Canada')
plt.show()

# %%
df_decades.describe()
# Out:
#                 1980           1990           2000
# count      15.000000      15.000000      15.000000
# mean    44418.333333   85594.666667   97471.533333
# std     44190.676455   68237.560246  100583.204205
# min      7613.000000   30028.000000   13629.000000
# 25%     16698.000000   39259.000000   36101.500000
# 50%     30638.000000   56915.000000   65794.000000
# 75%     59183.000000  104451.500000  105505.500000
# max    179171.000000  261966.000000  340385.000000

# %%
Q3=df_decades.quantile(0.75)  # 3 char vect
Q1=df_decades.quantile(0.25)  # 3 char vect
outliers_limit = Q3 + 1.5*(Q3-Q1)  # 3 char vect
outliers_limit
df_decades[df_decades['2000'] > outliers_limit[2]]
# Out:
#           1980    1990    2000
# Country
# India    82154  180395  303591
# China    32003  161528  340385

# %%
# df_can.set_index('Country', inplace=True)
df_tot = pd.DataFrame(df_can[years].transpose().sum(axis=1))
df_tot.index = map(int,df_tot.index)
df_tot.reset_index(inplace=True)

# %%
df_tot.head()
# Out:
#    index       0
# 0   1980   99137
# 1   1981  110563
# 2   1982  104271
# 3   1983   75550
# 4   1984   73417

# %%
df_tot.columns = ['year','total']

# %%
df_tot.head()
# Out:
#    year   total
# 0  1980   99137
# 1  1981  110563
# 2  1982  104271
# 3  1983   75550
# 4  1984   73417

# %%
df_tot.plot(kind='scatter', x='year', y='total', figsize=(10, 6), color='darkblue')

plt.title('Total Immigration to Canada from 1980 - 2013')
plt.xlabel('Year')
plt.ylabel('Number of Immigrants')

plt.show()

# %%
x = df_tot['year']
y = df_tot['total']
fit = np.polyfit(x,y,deg=1)
fit
# Out:
# array([ 5.56709228e+03, -1.09261952e+07])

# %%
# %matplotlib inline

df_tot.plot(kind = 'scatter', x='year', y = 'total', figsize=(20,10), color='darkblue')


plt.plot(x, fit[0]*x+fit[1], color='red')
plt.annotate('y={0:.0f}*x + {1:.0f}'.format(fit[0], fit[1]),
             xy = (2000,150000), 
            fontsize=22)
# # print(f'No. Immigrants = {fit[0]}*Year + {fit[1]}')

plt.title('Total Immigration to Canada from 1980 - 2013')
plt.xlabel('Year')
plt.ylabel('Number of Immigrants')

plt.show()

# %%
df_can.head()
# Out:
#                Continent           Region             DevName  1980  1981  \
# Country
# Afghanistan         Asia    Southern Asia  Developing regions    16    39
# Albania           Europe  Southern Europe   Developed regions     1     0
# Algeria           Africa  Northern Africa  Developing regions    80    67
# American Samoa   Oceania        Polynesia  Developing regions     0     1
# Andorra           Europe  Southern Europe   Developed regions     0     0
#
#                 1982  1983  1984  1985  1986  ...  2013  Unnamed: 43  \
# Country                                       ...
# Afghanistan       39    47    71   340   496  ...  2004          NaN
# Albania            0     0     0     0     1  ...   603          NaN
# Algeria           71    69    63    44    69  ...  4331          NaN
# American Samoa     0     0     0     0     0  ...     0          NaN
# Andorra            0     0     0     0     2  ...     1          NaN
#
# ...

# %%
df_oceania = df_can.loc[['Denmark', 'Norway','Sweden'], years]
df_oceania_total = df_oceania.transpose().sum(axis=1)

# %%
df_oceania_total = pd.DataFrame(data=df_oceania_total)
df_oceania_total.reset_index(inplace=True)

df_oceania_total
# Out:
#    index    0
# 0   1980  669
# 1   1981  678
# 2   1982  627
# 3   1983  333
# 4   1984  252
# 5   1985  285
# 6   1986  336
# 7   1987  387
# 8   1988  373
# 9   1989  387
# 10  1990  331
# 11  1991  381
# 12  1992  411
# 13  1993  481
# 14  1994  345
# 15  1995  352
# 16  1996  301
# 17  1997  338
# 18  1998  217
# 19  1999  287
# 20  2000  287
# 21  2001  343
# 22  2002  293
# 23  2003  327
# 24  2004  291
# 25  2005  324
# 26  2006  293
# 27  2007  363
# 28  2008  339
# 29  2009  323
# 30  2010  297
# 31  2011  276
# 32  2012  287
# 33  2013  280

# %%
df_oceania_total.columns=['year', 'total']
df_oceania_total
# Out:
#     year  total
# 0   1980    669
# 1   1981    678
# 2   1982    627
# 3   1983    333
# 4   1984    252
# 5   1985    285
# 6   1986    336
# 7   1987    387
# 8   1988    373
# 9   1989    387
# 10  1990    331
# 11  1991    381
# 12  1992    411
# 13  1993    481
# 14  1994    345
# 15  1995    352
# 16  1996    301
# 17  1997    338
# 18  1998    217
# 19  1999    287
# 20  2000    287
# 21  2001    343
# 22  2002    293
# 23  2003    327
# 24  2004    291
# 25  2005    324
# 26  2006    293
# 27  2007    363
# 28  2008    339
# 29  2009    323
# 30  2010    297
# 31  2011    276
# 32  2012    287
# 33  2013    280

# %%
df_oceania_total.plot(kind='scatter', x='year', y='total', color='darkblue')
plt.xlabel('Year')
plt.ylabel('Number of immigrants')
plt.title('Immigration trend to Canada from Denmark, Sweden and Norway 1980-2013')
plt.xticks(['1980', '1990', '2000'])
plt.show()

# %%
x = list(map(float, df_oceania_total['year']))   # year on x-axis
y = list(map(float, df_oceania_total['total']))     # total on y-axis
fit = np.polyfit(x, y, deg=1)

fit
# Out:
# array([-6.14698243e+00,  1.26281563e+04])

# %%
df_oceania_total.plot(kind='scatter', x='year', y='total', color='darkblue')
plt.xlabel('Year')
plt.ylabel('Number of immigrants')
plt.title('Immigration trend to Canada from Denmark, Sweden and Norway 1980-2013')
plt.xticks(['1980', '1990', '2000', '2010'])
plt.plot(x,x*fit[0]+fit[1], color='red')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-255-199f21145c7e> in <module>
#       4 plt.title('Immigration trend to Canada from Denmark, Sweden and Norway 1980-2013')
#       5 plt.xticks(['1980', '1990', '2000', '2010'])
# ----> 6 plt.plot(x,x*fit[0]+fit[1], color='red')
#       7 plt.show()
#
# TypeError: can't multiply sequence by non-int of type 'numpy.float64'

# %%
# transposed dataframe
df_can_t = df_can[years].transpose()

# cast the Years (the index) to type int
df_can_t.index = map(int, df_can_t.index)

# let's label the index. This will automatically be the column name when we reset the index
df_can_t.index.name = 'Year'

# reset index to bring the Year in as a column
df_can_t.reset_index(inplace=True)

# view the changes
df_can_t.head()
# Out:
# Country  Year  Afghanistan  Albania  Algeria  American Samoa  Andorra  Angola  \
# 0        1980           16        1       80               0        0       1
# 1        1981           39        0       67               1        0       3
# 2        1982           39        0       71               0        0       6
# 3        1983           47        0       69               0        0       6
# 4        1984           71        0       63               0        0       4
#
# Country  Antigua and Barbuda  Argentina  Armenia  ...  \
# 0                          0        368        0  ...
# 1                          0        426        0  ...
# 2                          0        626        0  ...
# 3                          0        241        0  ...
# 4                         42        237        0  ...
#
# Country  United States of America  Uruguay  Uzbekistan  Vanuatu  \
# 0                            9378      128           0        0
# ...

# %%
# normalize Brazil data
norm_brazil = (df_can_t['Brazil'] - df_can_t['Brazil'].min()) / (df_can_t['Brazil'].max() - df_can_t['Brazil'].min())

# normalize Argentina data
norm_argentina = (df_can_t['Argentina'] - df_can_t['Argentina'].min()) / (df_can_t['Argentina'].max() - df_can_t['Argentina'].min())

# %%
# Brazil
ax0 = df_can_t.plot(kind='scatter',
                    x='Year',
                    y='Brazil',
                    figsize=(14, 8),
                    alpha=0.5,  # transparency
                    color='green',
                    s=norm_brazil * 2000 + 10,  # pass in weights 
                    xlim=(1975, 2015)
                    )

# Argentina
ax1 = df_can_t.plot(kind='scatter',
                    x='Year',
                    y='Argentina',
                    alpha=0.5,
                    color="blue",
                    s=norm_argentina * 2000 + 10,
                    ax=ax0
                    )

ax0.set_ylabel('Number of Immigrants')
ax0.set_title('Immigration from Brazil and Argentina from 1980 to 2013')
ax0.legend(['Brazil', 'Argentina'], loc='upper left', fontsize='x-large')

# %%
df_can_t = df_can[years].transpose()
df_can_t.index = map(int, df_can_t.index)
df_can_t.index.name = 'year'

# %%
df_can_t.reset_index(inplace=True)

# %%
df_can_t.head()
# Out:
# Country  year  Afghanistan  Albania  Algeria  American Samoa  Andorra  Angola  \
# 0        1980           16        1       80               0        0       1
# 1        1981           39        0       67               1        0       3
# 2        1982           39        0       71               0        0       6
# 3        1983           47        0       69               0        0       6
# 4        1984           71        0       63               0        0       4
#
# Country  Antigua and Barbuda  Argentina  Armenia  ...  \
# 0                          0        368        0  ...
# 1                          0        426        0  ...
# 2                          0        626        0  ...
# 3                          0        241        0  ...
# 4                         42        237        0  ...
#
# Country  United States of America  Uruguay  Uzbekistan  Vanuatu  \
# 0                            9378      128           0        0
# ...

# %%
#xnorm = (x-xmin)/(xmax-xmin)
norm_china = (df_can_t['China']-df_can_t['China'].min())/(df_can_t['China'].max()-df_can_t['China'].min())
norm_india = (df_can_t['India']-df_can_t['India'].min())/(df_can_t['India'].max()-df_can_t['India'].min())

# %%
# bubble plot China
ax0 = df_can_t.plot(kind='scatter',
                   x='year',
                   y='China',
                   color = 'darkred',
                   alpha = 0.5,
                   figsize=(14,8),
                   s = norm_china*2000+10,
                   xlim = (1975,2015))

#bubble plot India
ax1 = df_can_t.plot(kind='scatter',
                   x='year',
                   y='India',
                   color='darkblue',
                   alpha=0.5,
                   ax=ax0,
                   s=2000*norm_india+10)

plt.legend(['China', 'India'], loc='upper left', fontsize=22)
plt.show()
